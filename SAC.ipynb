# %% [markdown]
# <a href="https://colab.research.google.com/github/Aryan8912/CUDA_Practice/blob/main/SAC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class ActorCriticNetwork(keras.Model):
  def __init__(self, n_actions, fc1_dims=1024, fc2_dims=512,
               name='actor_critic', chkpt_dir='tmp/actor_critic'):
    super(ActorCriticNetwork, self).__init__()
    self.fc1_dims = fc1_dims
    self.fc2_dims = fc2_dims
    self.n_actions = n_actions
    self.model_name = name
    self.checkpoint_dir = chkpt_dir
    self.checkpoint_file = os.path.join(self.checkpoint_dir, name+'_ac.weights.h5')

    self.fc1 = Dense(self.fc1_dims, activation='relu')
    self.fc2 = Dense(self.fc2_dims, activation='relu')
    self.v = Dense(1, activation=None)
    self.pi = Dense(n_actions, activation='softmax')

  def call(self, state):
    value = self.fc1(state)
    value = self.fc2(value)

    v = self.v(value)
    pi = self.pi(value)

    return v, pi

# %%
import tensorflow as tf
from tensorflow.keras.optimizers import Adam
import tensorflow_probability as tfp

class Agent:
    def __init__(self, alpha=0.0003, gamma=0.99, n_actions=2):
        self.gamma = gamma
        self.n_actions = n_actions
        self.action = None
        self.action_space = [i for i in range(self.n_actions)]

        self.actor_critic = ActorCriticNetwork(n_actions=n_actions)

        self.actor_critic.compile(optimizer=Adam(learning_rate=alpha))


    def choose_action(self, observation):
        state = tf.convert_to_tensor([observation])
        _, probs = self.actor_critic(state)

        action_probabilities = tfp.distributions.Categorical(probs=probs)
        action = action_probabilities.sample()
        log_prob = action_probabilities.log_prob(action)
        self.action = action

        return action.numpy()[0]

    def save_models(self):
        print('... saving models ...')
        self.actor_critic.save_weights(self.actor_critic.checkpoint_file)

    def load_models(self):
        print('... loading models ...')
        self.actor_critic.load_weights(self.actor_critic.checkpoint_file)

    def learn(self, state, reward, state_, done):
        state = tf.convert_to_tensor([state], dtype=tf.float32)
        state_ = tf.convert_to_tensor([state_], dtype=tf.float32)
        reward = tf.convert_to_tensor(reward, dtype=tf.float32) # not fed to NN
        with tf.GradientTape(persistent=True) as tape:
            state_value, probs = self.actor_critic(state)
            state_value_, _ = self.actor_critic(state_)
            state_value = tf.squeeze(state_value)
            state_value_ = tf.squeeze(state_value_)

            action_probs = tfp.distributions.Categorical(probs=probs)
            log_prob = action_probs.log_prob(self.action)

            delta = reward + self.gamma*state_value_*(1-int(done)) - state_value
            actor_loss = -log_prob*delta
            critic_loss = delta**2
            total_loss = actor_loss + critic_loss

        gradient = tape.gradient(total_loss, self.actor_critic.trainable_variables)
        self.actor_critic.optimizer.apply_gradients(zip(
            gradient, self.actor_critic.trainable_variables))

# %%
import tensorflow as tf
from tensorflow.keras.optimizers import Adam
import tensorflow_probability as tfp

class Agent:
    def __init__(self, alpha=0.0003, gamma=0.99, n_actions=2):
        self.gamma = gamma
        self.n_actions = n_actions
        self.action = None
        self.action_space = [i for i in range(self.n_actions)]

        self.actor_critic = ActorCriticNetwork(n_actions=n_actions)

        self.actor_critic.compile(optimizer=Adam(learning_rate=alpha))


    def choose_action(self, observation):
        state = tf.convert_to_tensor([observation])
        _, probs = self.actor_critic(state)

        action_probabilities = tfp.distributions.Categorical(probs=probs)
        action = action_probabilities.sample()
        log_prob = action_probabilities.log_prob(action)
        self.action = action

        return action.numpy()[0]

    def save_models(self):
        print('... saving models ...')
        self.actor_critic.save_weights(self.actor_critic.checkpoint_file)

    def load_models(self):
        print('... loading models ...')
        self.actor_critic.load_weights(self.actor_critic.checkpoint_file)

    def learn(self, state, reward, state_, done):
        state = tf.convert_to_tensor([state], dtype=tf.float32)
        state_ = tf.convert_to_tensor([state_], dtype=tf.float32)
        reward = tf.convert_to_tensor(reward, dtype=tf.float32) # not fed to NN
        with tf.GradientTape(persistent=True) as tape:
            state_value, probs = self.actor_critic(state)
            state_value_, _ = self.actor_critic(state_)
            state_value = tf.squeeze(state_value)
            state_value_ = tf.squeeze(state_value_)

            action_probs = tfp.distributions.Categorical(probs=probs)
            log_prob = action_probs.log_prob(self.action)

            delta = reward + self.gamma*state_value_*(1-int(done)) - state_value
            actor_loss = -log_prob*delta
            critic_loss = delta**2
            total_loss = actor_loss + critic_loss

        gradient = tape.gradient(total_loss, self.actor_critic.trainable_variables)
        self.actor_critic.optimizer.apply_gradients(zip(
            gradient, self.actor_critic.trainable_variables))

# %%
import numpy as np
import matplotlib.pyplot as plt

def plot_learning_curve(x, scores, figure_file):
  running_avg = np.zeros(len(scores))
  for i in range(len(running_avg)):
    running_avg[i] = np.mean(score[max(0, i-100):(i+1)])
  plt.plot(x, running_avg)
  plt.title('Running average of previous 100 scores')
  plt.savefig(figure_file)

# %%
import os
import gym
import numpy as np
from gym import wrappers

if __name__ == '__main__':
    #env = gym.make('LunarLander-v2')
    env = gym.make('CartPole-v0')
    agent = Agent(alpha=1e-5, n_actions=env.action_space.n)
    n_games = 1800
    # uncomment this line and do a mkdir tmp && mkdir video if you want to
    # record video of the agent playing the game.
    #env = wrappers.Monitor(env, 'tmp/video', video_callable=lambda episode_id: True, force=True)
    filename = 'cartpole_1e-5_1024x512_1800games.png'

    figure_file = 'plots/' + filename

    best_score = env.reward_range[0]
    score_history = []
    load_checkpoint = False

    if load_checkpoint:
        agent.load_models()

    # Create the directory if it doesn't exist
    if not os.path.exists(agent.actor_critic.checkpoint_dir):
        os.makedirs(agent.actor_critic.checkpoint_dir)

    for i in range(n_games):
        observation = env.reset()
        done = False
        score = 0
        while not done:
            action = agent.choose_action(observation)
            observation_, reward, done, info = env.step(action)
            score += reward
            if not load_checkpoint:
                agent.learn(observation, reward, observation_, done)
            observation = observation_
        score_history.append(score)
        avg_score = np.mean(score_history[-100:])

        if avg_score > best_score:
            best_score = avg_score
            if not load_checkpoint:
                agent.save_models()

        print('episode ', i, 'score %.1f' % score, 'avg_score %.1f' % avg_score)

    if not load_checkpoint:
        x = [i+1 for i in range(n_games)]
        plot_learning_curve(x, score_history, figure_file)
# Out:
# /usr/local/lib/python3.11/dist-packages/gym/envs/registration.py:593: UserWarning: WARN: The environment CartPole-v0 is out of date. You should consider upgrading to version `v1`.
#   logger.warn(
# /usr/local/lib/python3.11/dist-packages/gym/core.py:317: DeprecationWarning: WARN: Initializing wrapper in old step API which returns one bool instead of two. It is recommended to set `new_step_api=True` to use new step API. This will be the default behaviour in future.
#   deprecation(
# /usr/local/lib/python3.11/dist-packages/gym/wrappers/step_api_compatibility.py:39: DeprecationWarning: WARN: Initializing environment in old step API which returns one bool instead of two. It is recommended to set `new_step_api=True` to use new step API. This will be the default behaviour in future.
#   deprecation(
# /usr/local/lib/python3.11/dist-packages/gym/utils/passive_env_checker.py:241: DeprecationWarning: `np.bool8` is a deprecated alias for `np.bool_`.  (Deprecated NumPy 1.24)
#   if not isinstance(terminated, (bool, np.bool8)):
# ... saving models ...
# episode  0 score 27.0 avg_score 27.0
# episode  1 score 22.0 avg_score 24.5
# episode  2 score 24.0 avg_score 24.3
# episode  3 score 15.0 avg_score 22.0
# episode  4 score 24.0 avg_score 22.4
# ... saving models ...
# episode  5 score 51.0 avg_score 27.2
# episode  6 score 27.0 avg_score 27.1
# episode  7 score 22.0 avg_score 26.5
# episode  8 score 25.0 avg_score 26.3
# episode  9 score 9.0 avg_score 24.6
# episode  10 score 10.0 avg_score 23.3
# episode  11 score 33.0 avg_score 24.1
# episode  12 score 18.0 avg_score 23.6
# episode  13 score 12.0 avg_score 22.8
# episode  14 score 10.0 avg_score 21.9
# episode  15 score 34.0 avg_score 22.7
# episode  16 score 16.0 avg_score 22.3
# episode  17 score 61.0 avg_score 24.4
# episode  18 score 31.0 avg_score 24.8
# episode  19 score 12.0 avg_score 24.1
# episode  20 score 15.0 avg_score 23.7
# episode  21 score 32.0 avg_score 24.1
# episode  22 score 43.0 avg_score 24.9
# episode  23 score 16.0 avg_score 24.5
# episode  24 score 29.0 avg_score 24.7
# episode  25 score 18.0 avg_score 24.5
# episode  26 score 38.0 avg_score 25.0
# episode  27 score 29.0 avg_score 25.1
# episode  28 score 15.0 avg_score 24.8
# episode  29 score 31.0 avg_score 25.0
# episode  30 score 45.0 avg_score 25.6
# episode  31 score 63.0 avg_score 26.8
# episode  32 score 18.0 avg_score 26.5
# episode  33 score 16.0 avg_score 26.2
# episode  34 score 16.0 avg_score 25.9
# episode  35 score 36.0 avg_score 26.2
# episode  36 score 18.0 avg_score 26.0
# episode  37 score 17.0 avg_score 25.7
# episode  38 score 23.0 avg_score 25.7
# episode  39 score 14.0 avg_score 25.4
# episode  40 score 15.0 avg_score 25.1
# episode  41 score 21.0 avg_score 25.0
# episode  42 score 22.0 avg_score 25.0
# episode  43 score 14.0 avg_score 24.7
# episode  44 score 28.0 avg_score 24.8
# episode  45 score 19.0 avg_score 24.7
# episode  46 score 28.0 avg_score 24.7
# episode  47 score 51.0 avg_score 25.3
# episode  48 score 22.0 avg_score 25.2
# episode  49 score 17.0 avg_score 25.0
# episode  50 score 41.0 avg_score 25.4
# episode  51 score 36.0 avg_score 25.6
# episode  52 score 28.0 avg_score 25.6
# episode  53 score 13.0 avg_score 25.4
# episode  54 score 15.0 avg_score 25.2
# episode  55 score 25.0 avg_score 25.2
# episode  56 score 13.0 avg_score 25.0
# episode  57 score 13.0 avg_score 24.8
# episode  58 score 31.0 avg_score 24.9
# episode  59 score 34.0 avg_score 25.0
# episode  60 score 18.0 avg_score 24.9
# episode  61 score 16.0 avg_score 24.8
# episode  62 score 12.0 avg_score 24.6
# episode  63 score 38.0 avg_score 24.8
# episode  64 score 20.0 avg_score 24.7
# episode  65 score 21.0 avg_score 24.6
# episode  66 score 13.0 avg_score 24.5
# episode  67 score 10.0 avg_score 24.2
# episode  68 score 26.0 avg_score 24.3
# episode  69 score 26.0 avg_score 24.3
# episode  70 score 10.0 avg_score 24.1
# episode  71 score 48.0 avg_score 24.4
# episode  72 score 14.0 avg_score 24.3
# episode  73 score 19.0 avg_score 24.2
# episode  74 score 30.0 avg_score 24.3
# episode  75 score 27.0 avg_score 24.3
# episode  76 score 28.0 avg_score 24.4
# episode  77 score 18.0 avg_score 24.3
# episode  78 score 20.0 avg_score 24.2
# episode  79 score 19.0 avg_score 24.2
# episode  80 score 15.0 avg_score 24.1
# episode  81 score 27.0 avg_score 24.1
# episode  82 score 26.0 avg_score 24.1
# episode  83 score 19.0 avg_score 24.1
# episode  84 score 20.0 avg_score 24.0
# episode  85 score 27.0 avg_score 24.0
# episode  86 score 24.0 avg_score 24.0
# episode  87 score 10.0 avg_score 23.9
# episode  88 score 12.0 avg_score 23.8
# episode  89 score 18.0 avg_score 23.7
# episode  90 score 13.0 avg_score 23.6
# episode  91 score 16.0 avg_score 23.5
# episode  92 score 63.0 avg_score 23.9
# episode  93 score 22.0 avg_score 23.9
# episode  94 score 17.0 avg_score 23.8
# episode  95 score 32.0 avg_score 23.9
# episode  96 score 14.0 avg_score 23.8
# episode  97 score 41.0 avg_score 24.0
# episode  98 score 14.0 avg_score 23.9
# episode  99 score 11.0 avg_score 23.8
# episode  100 score 16.0 avg_score 23.6
# episode  101 score 20.0 avg_score 23.6
# episode  102 score 11.0 avg_score 23.5
# episode  103 score 16.0 avg_score 23.5
# episode  104 score 30.0 avg_score 23.6
# episode  105 score 20.0 avg_score 23.2
# episode  106 score 35.0 avg_score 23.3
# episode  107 score 23.0 avg_score 23.3
# episode  108 score 19.0 avg_score 23.3
# episode  109 score 12.0 avg_score 23.3
# episode  110 score 13.0 avg_score 23.3
# episode  111 score 9.0 avg_score 23.1
# episode  112 score 15.0 avg_score 23.1
# episode  113 score 13.0 avg_score 23.1
# episode  114 score 21.0 avg_score 23.2
# episode  115 score 15.0 avg_score 23.0
# episode  116 score 30.0 avg_score 23.1
# episode  117 score 11.0 avg_score 22.6
# episode  118 score 27.0 avg_score 22.6
# episode  119 score 24.0 avg_score 22.7
# episode  120 score 14.0 avg_score 22.7
# episode  121 score 33.0 avg_score 22.7
# episode  122 score 16.0 avg_score 22.4
# episode  123 score 14.0 avg_score 22.4
# episode  124 score 17.0 avg_score 22.3
# episode  125 score 60.0 avg_score 22.7
# episode  126 score 19.0 avg_score 22.5
# episode  127 score 15.0 avg_score 22.4
# episode  128 score 15.0 avg_score 22.4
# episode  129 score 19.0 avg_score 22.3
# episode  130 score 15.0 avg_score 22.0
# episode  131 score 19.0 avg_score 21.5
# episode  132 score 18.0 avg_score 21.5
# episode  133 score 22.0 avg_score 21.6
# episode  134 score 22.0 avg_score 21.7
# episode  135 score 31.0 avg_score 21.6
# episode  136 score 13.0 avg_score 21.6
# episode  137 score 12.0 avg_score 21.5
# episode  138 score 22.0 avg_score 21.5
# episode  139 score 18.0 avg_score 21.5
# episode  140 score 24.0 avg_score 21.6
# episode  141 score 13.0 avg_score 21.6
# episode  142 score 17.0 avg_score 21.5
# episode  143 score 17.0 avg_score 21.5
# episode  144 score 22.0 avg_score 21.5
# episode  145 score 15.0 avg_score 21.4
# episode  146 score 12.0 avg_score 21.3
# episode  147 score 12.0 avg_score 20.9
# episode  148 score 13.0 avg_score 20.8
# episode  149 score 10.0 avg_score 20.7
# episode  150 score 29.0 avg_score 20.6
# episode  151 score 28.0 avg_score 20.5
# episode  152 score 16.0 avg_score 20.4
# episode  153 score 36.0 avg_score 20.6
# episode  154 score 32.0 avg_score 20.8
# episode  155 score 36.0 avg_score 20.9
# episode  156 score 20.0 avg_score 21.0
# episode  157 score 11.0 avg_score 21.0
# episode  158 score 15.0 avg_score 20.8
# episode  159 score 13.0 avg_score 20.6
# episode  160 score 26.0 avg_score 20.7
# episode  161 score 22.0 avg_score 20.7
# episode  162 score 25.0 avg_score 20.9
# episode  163 score 25.0 avg_score 20.7
# episode  164 score 31.0 avg_score 20.8
# episode  165 score 38.0 avg_score 21.0
# episode  166 score 20.0 avg_score 21.1
# episode  167 score 30.0 avg_score 21.3
# episode  168 score 39.0 avg_score 21.4
# episode  169 score 31.0 avg_score 21.5
# episode  170 score 16.0 avg_score 21.5
# episode  171 score 12.0 avg_score 21.2
# episode  172 score 35.0 avg_score 21.4
# episode  173 score 20.0 avg_score 21.4
# episode  174 score 11.0 avg_score 21.2
# episode  175 score 17.0 avg_score 21.1
# episode  176 score 12.0 avg_score 20.9
# episode  177 score 19.0 avg_score 20.9
# episode  178 score 39.0 avg_score 21.1
# episode  179 score 12.0 avg_score 21.1
# episode  180 score 12.0 avg_score 21.0
# episode  181 score 65.0 avg_score 21.4
# episode  182 score 14.0 avg_score 21.3
# episode  183 score 27.0 avg_score 21.4
# episode  184 score 34.0 avg_score 21.5
# episode  185 score 14.0 avg_score 21.4
# episode  186 score 17.0 avg_score 21.3
# episode  187 score 17.0 avg_score 21.4
# episode  188 score 29.0 avg_score 21.6
# episode  189 score 16.0 avg_score 21.5
# episode  190 score 19.0 avg_score 21.6
# episode  191 score 37.0 avg_score 21.8
# episode  192 score 23.0 avg_score 21.4
# episode  193 score 12.0 avg_score 21.3
# episode  194 score 16.0 avg_score 21.3
# episode  195 score 40.0 avg_score 21.4
# episode  196 score 25.0 avg_score 21.5
# episode  197 score 19.0 avg_score 21.3
# episode  198 score 25.0 avg_score 21.4
# episode  199 score 24.0 avg_score 21.5
# episode  200 score 27.0 avg_score 21.6
# episode  201 score 18.0 avg_score 21.6
# episode  202 score 41.0 avg_score 21.9
# episode  203 score 15.0 avg_score 21.9
# episode  204 score 15.0 avg_score 21.7
# episode  205 score 21.0 avg_score 21.7
# episode  206 score 19.0 avg_score 21.6
# episode  207 score 29.0 avg_score 21.6
# episode  208 score 15.0 avg_score 21.6
# episode  209 score 30.0 avg_score 21.8
# episode  210 score 28.0 avg_score 21.9
# episode  211 score 12.0 avg_score 22.0
# episode  212 score 27.0 avg_score 22.1
# episode  213 score 29.0 avg_score 22.2
# episode  214 score 23.0 avg_score 22.3
# episode  215 score 19.0 avg_score 22.3
# episode  216 score 15.0 avg_score 22.1
# episode  217 score 45.0 avg_score 22.5
# episode  218 score 12.0 avg_score 22.3
# episode  219 score 20.0 avg_score 22.3
# episode  220 score 15.0 avg_score 22.3
# episode  221 score 15.0 avg_score 22.1
# episode  222 score 28.0 avg_score 22.2
# episode  223 score 14.0 avg_score 22.2
# episode  224 score 22.0 avg_score 22.3
# episode  225 score 23.0 avg_score 21.9
# episode  226 score 9.0 avg_score 21.8
# episode  227 score 13.0 avg_score 21.8
# episode  228 score 17.0 avg_score 21.8
# episode  229 score 20.0 avg_score 21.8
# episode  230 score 22.0 avg_score 21.9
# episode  231 score 15.0 avg_score 21.9
# episode  232 score 20.0 avg_score 21.9
# episode  233 score 11.0 avg_score 21.8
# episode  234 score 13.0 avg_score 21.7
# episode  235 score 28.0 avg_score 21.7
# episode  236 score 21.0 avg_score 21.7
# episode  237 score 19.0 avg_score 21.8
# episode  238 score 15.0 avg_score 21.7
# episode  239 score 14.0 avg_score 21.7
# episode  240 score 24.0 avg_score 21.7
# episode  241 score 27.0 avg_score 21.8
# episode  242 score 27.0 avg_score 21.9
# episode  243 score 71.0 avg_score 22.5
# episode  244 score 20.0 avg_score 22.5
# episode  245 score 44.0 avg_score 22.8
# episode  246 score 11.0 avg_score 22.7
# episode  247 score 12.0 avg_score 22.7
# episode  248 score 35.0 avg_score 23.0
# episode  249 score 35.0 avg_score 23.2
# episode  250 score 30.0 avg_score 23.2
# episode  251 score 15.0 avg_score 23.1
# episode  252 score 26.0 avg_score 23.2
# episode  253 score 42.0 avg_score 23.2
# episode  254 score 19.0 avg_score 23.1
# episode  255 score 15.0 avg_score 22.9
# episode  256 score 39.0 avg_score 23.1
# episode  257 score 17.0 avg_score 23.2
# episode  258 score 8.0 avg_score 23.1
# episode  259 score 13.0 avg_score 23.1
# episode  260 score 29.0 avg_score 23.1
# episode  261 score 16.0 avg_score 23.1
# episode  262 score 31.0 avg_score 23.1
# episode  263 score 20.0 avg_score 23.1
# episode  264 score 12.0 avg_score 22.9
# episode  265 score 20.0 avg_score 22.7
# episode  266 score 14.0 avg_score 22.6
# episode  267 score 53.0 avg_score 22.9
# episode  268 score 12.0 avg_score 22.6
# episode  269 score 29.0 avg_score 22.6
# episode  270 score 15.0 avg_score 22.6
# episode  271 score 22.0 avg_score 22.7
# episode  272 score 20.0 avg_score 22.5
# episode  273 score 16.0 avg_score 22.5
# episode  274 score 11.0 avg_score 22.5
# episode  275 score 15.0 avg_score 22.5
# episode  276 score 17.0 avg_score 22.5
# episode  277 score 18.0 avg_score 22.5
# episode  278 score 59.0 avg_score 22.7
# episode  279 score 9.0 avg_score 22.7
# episode  280 score 33.0 avg_score 22.9
# episode  281 score 20.0 avg_score 22.4
# episode  282 score 11.0 avg_score 22.4
# episode  283 score 17.0 avg_score 22.3
# episode  284 score 18.0 avg_score 22.1
# episode  285 score 19.0 avg_score 22.2
# episode  286 score 29.0 avg_score 22.3
# episode  287 score 14.0 avg_score 22.3
# episode  288 score 23.0 avg_score 22.2
# episode  289 score 44.0 avg_score 22.5
# episode  290 score 16.0 avg_score 22.5
# episode  291 score 10.0 avg_score 22.2
# episode  292 score 13.0 avg_score 22.1
# episode  293 score 15.0 avg_score 22.1
# episode  294 score 11.0 avg_score 22.1
# episode  295 score 34.0 avg_score 22.0
# episode  296 score 16.0 avg_score 21.9
# episode  297 score 24.0 avg_score 22.0
# episode  298 score 26.0 avg_score 22.0
# episode  299 score 16.0 avg_score 21.9
# episode  300 score 44.0 avg_score 22.1
# episode  301 score 25.0 avg_score 22.1
# episode  302 score 18.0 avg_score 21.9
# episode  303 score 18.0 avg_score 21.9
# episode  304 score 34.0 avg_score 22.1
# episode  305 score 91.0 avg_score 22.8
# episode  306 score 21.0 avg_score 22.9
# episode  307 score 23.0 avg_score 22.8
# episode  308 score 19.0 avg_score 22.8
# episode  309 score 13.0 avg_score 22.7
# episode  310 score 33.0 avg_score 22.7
# episode  311 score 28.0 avg_score 22.9
# episode  312 score 37.0 avg_score 23.0
# episode  313 score 34.0 avg_score 23.0
# episode  314 score 25.0 avg_score 23.1
# episode  315 score 29.0 avg_score 23.1
# episode  316 score 30.0 avg_score 23.3
# episode  317 score 26.0 avg_score 23.1
# episode  318 score 36.0 avg_score 23.4
# episode  319 score 33.0 avg_score 23.5
# episode  320 score 14.0 avg_score 23.5
# episode  321 score 13.0 avg_score 23.4
# episode  322 score 9.0 avg_score 23.3
# episode  323 score 18.0 avg_score 23.3
# episode  324 score 16.0 avg_score 23.2
# episode  325 score 33.0 avg_score 23.3
# episode  326 score 15.0 avg_score 23.4
# episode  327 score 32.0 avg_score 23.6
# episode  328 score 12.0 avg_score 23.5
# episode  329 score 30.0 avg_score 23.6
# episode  330 score 21.0 avg_score 23.6
# episode  331 score 18.0 avg_score 23.7
# episode  332 score 22.0 avg_score 23.7
# episode  333 score 11.0 avg_score 23.7
# episode  334 score 18.0 avg_score 23.7
# episode  335 score 32.0 avg_score 23.8
# episode  336 score 12.0 avg_score 23.7
# episode  337 score 22.0 avg_score 23.7
# episode  338 score 17.0 avg_score 23.7
# episode  339 score 47.0 avg_score 24.1
# episode  340 score 19.0 avg_score 24.0
# episode  341 score 33.0 avg_score 24.1
# episode  342 score 14.0 avg_score 23.9
# episode  343 score 30.0 avg_score 23.5
# episode  344 score 45.0 avg_score 23.8
# episode  345 score 23.0 avg_score 23.6
# episode  346 score 29.0 avg_score 23.8
# episode  347 score 13.0 avg_score 23.8
# episode  348 score 51.0 avg_score 23.9
# episode  349 score 43.0 avg_score 24.0
# episode  350 score 20.0 avg_score 23.9
# episode  351 score 44.0 avg_score 24.2
# episode  352 score 70.0 avg_score 24.6
# episode  353 score 22.0 avg_score 24.4
# episode  354 score 40.0 avg_score 24.6
# episode  355 score 25.0 avg_score 24.7
# episode  356 score 28.0 avg_score 24.6
# episode  357 score 13.0 avg_score 24.6
# episode  358 score 39.0 avg_score 24.9
# episode  359 score 33.0 avg_score 25.1
# episode  360 score 14.0 avg_score 24.9
# episode  361 score 33.0 avg_score 25.1
# episode  362 score 25.0 avg_score 25.1
# episode  363 score 18.0 avg_score 25.0
# episode  364 score 19.0 avg_score 25.1
# episode  365 score 41.0 avg_score 25.3
# episode  366 score 50.0 avg_score 25.7
# episode  367 score 34.0 avg_score 25.5
# episode  368 score 15.0 avg_score 25.5
# episode  369 score 33.0 avg_score 25.6
# episode  370 score 34.0 avg_score 25.8
# episode  371 score 45.0 avg_score 26.0
# episode  372 score 24.0 avg_score 26.0
# episode  373 score 15.0 avg_score 26.0
# episode  374 score 26.0 avg_score 26.2
# episode  375 score 33.0 avg_score 26.3
# episode  376 score 20.0 avg_score 26.4
# episode  377 score 28.0 avg_score 26.5
# episode  378 score 14.0 avg_score 26.0
# episode  379 score 17.0 avg_score 26.1
# episode  380 score 58.0 avg_score 26.4
# episode  381 score 14.0 avg_score 26.3
# episode  382 score 17.0 avg_score 26.4
# episode  383 score 38.0 avg_score 26.6
# episode  384 score 39.0 avg_score 26.8
# episode  385 score 22.0 avg_score 26.8
# episode  386 score 45.0 avg_score 27.0
# episode  387 score 20.0 avg_score 27.0
# episode  388 score 20.0 avg_score 27.0
# episode  389 score 11.0 avg_score 26.7
# episode  390 score 41.0 avg_score 26.9
# episode  391 score 18.0 avg_score 27.0
# episode  392 score 25.0 avg_score 27.1
# ... saving models ...
# episode  393 score 38.0 avg_score 27.3
# ... saving models ...
# episode  394 score 21.0 avg_score 27.4
# episode  395 score 17.0 avg_score 27.3
# episode  396 score 16.0 avg_score 27.3
# ... saving models ...
# episode  397 score 46.0 avg_score 27.5
# episode  398 score 22.0 avg_score 27.4
# ... saving models ...
# episode  399 score 46.0 avg_score 27.8
# episode  400 score 44.0 avg_score 27.8
# episode  401 score 21.0 avg_score 27.7
# episode  402 score 15.0 avg_score 27.7
# ... saving models ...
# episode  403 score 27.0 avg_score 27.8
# episode  404 score 21.0 avg_score 27.6
# episode  405 score 14.0 avg_score 26.9
# episode  406 score 20.0 avg_score 26.9
# episode  407 score 14.0 avg_score 26.8
# episode  408 score 30.0 avg_score 26.9
# ... saving models ...
# episode  409 score 104.0 avg_score 27.8
# ... saving models ...
# episode  410 score 39.0 avg_score 27.9
# episode  411 score 11.0 avg_score 27.7
# episode  412 score 14.0 avg_score 27.4
# episode  413 score 13.0 avg_score 27.2
# episode  414 score 42.0 avg_score 27.4
# episode  415 score 14.0 avg_score 27.3
# episode  416 score 33.0 avg_score 27.3
# episode  417 score 29.0 avg_score 27.3
# episode  418 score 31.0 avg_score 27.3
# episode  419 score 24.0 avg_score 27.2
# episode  420 score 24.0 avg_score 27.3
# episode  421 score 43.0 avg_score 27.6
# episode  422 score 13.0 avg_score 27.6
# episode  423 score 29.0 avg_score 27.7
# ... saving models ...
# episode  424 score 36.0 avg_score 27.9
# ... saving models ...
# episode  425 score 75.0 avg_score 28.4
# ... saving models ...
# episode  426 score 46.0 avg_score 28.7
# episode  427 score 25.0 avg_score 28.6
# episode  428 score 16.0 avg_score 28.6
# ... saving models ...
# episode  429 score 38.0 avg_score 28.7
# ... saving models ...
# episode  430 score 24.0 avg_score 28.7
# ... saving models ...
# episode  431 score 44.0 avg_score 29.0
# ... saving models ...
# episode  432 score 23.0 avg_score 29.0
# ... saving models ...
# episode  433 score 50.0 avg_score 29.4
# episode  434 score 10.0 avg_score 29.3
# episode  435 score 25.0 avg_score 29.2
# episode  436 score 14.0 avg_score 29.3
# episode  437 score 33.0 avg_score 29.4
# ... saving models ...
# episode  438 score 20.0 avg_score 29.4
# episode  439 score 21.0 avg_score 29.1
# episode  440 score 35.0 avg_score 29.3
# episode  441 score 19.0 avg_score 29.2
# episode  442 score 29.0 avg_score 29.3
# episode  443 score 39.0 avg_score 29.4
# episode  444 score 26.0 avg_score 29.2
# episode  445 score 36.0 avg_score 29.4
# ... saving models ...
# episode  446 score 46.0 avg_score 29.5
# ... saving models ...
# episode  447 score 48.0 avg_score 29.9
# episode  448 score 37.0 avg_score 29.7
# ... saving models ...
# episode  449 score 85.0 avg_score 30.1
# episode  450 score 19.0 avg_score 30.1
# episode  451 score 13.0 avg_score 29.8
# episode  452 score 28.0 avg_score 29.4
# episode  453 score 16.0 avg_score 29.4
# episode  454 score 22.0 avg_score 29.2
# episode  455 score 55.0 avg_score 29.5
# episode  456 score 34.0 avg_score 29.5
# episode  457 score 14.0 avg_score 29.5
# episode  458 score 20.0 avg_score 29.4
# episode  459 score 15.0 avg_score 29.2
# episode  460 score 58.0 avg_score 29.6
# episode  461 score 34.0 avg_score 29.6
# episode  462 score 42.0 avg_score 29.8
# ... saving models ...
# episode  463 score 58.0 avg_score 30.2
# ... saving models ...
# episode  464 score 26.0 avg_score 30.3
# episode  465 score 18.0 avg_score 30.0
# episode  466 score 35.0 avg_score 29.9
# episode  467 score 19.0 avg_score 29.7
# episode  468 score 16.0 avg_score 29.7
# episode  469 score 36.0 avg_score 29.8
# episode  470 score 44.0 avg_score 29.9
# episode  471 score 23.0 avg_score 29.6
# episode  472 score 14.0 avg_score 29.6
# episode  473 score 26.0 avg_score 29.7
# episode  474 score 20.0 avg_score 29.6
# episode  475 score 20.0 avg_score 29.5
# episode  476 score 37.0 avg_score 29.6
# episode  477 score 24.0 avg_score 29.6
# episode  478 score 72.0 avg_score 30.2
# episode  479 score 20.0 avg_score 30.2
# episode  480 score 11.0 avg_score 29.7
# episode  481 score 42.0 avg_score 30.0
# episode  482 score 19.0 avg_score 30.0
# episode  483 score 27.0 avg_score 29.9
# episode  484 score 21.0 avg_score 29.8
# episode  485 score 49.0 avg_score 30.0
# episode  486 score 29.0 avg_score 29.9
# episode  487 score 32.0 avg_score 30.0
# episode  488 score 15.0 avg_score 29.9
# episode  489 score 25.0 avg_score 30.1
# episode  490 score 40.0 avg_score 30.1
# episode  491 score 9.0 avg_score 30.0
# episode  492 score 24.0 avg_score 30.0
# ... saving models ...
# episode  493 score 71.0 avg_score 30.3
# episode  494 score 20.0 avg_score 30.3
# ... saving models ...
# episode  495 score 38.0 avg_score 30.5
# ... saving models ...
# episode  496 score 25.0 avg_score 30.6
# episode  497 score 46.0 avg_score 30.6
# ... saving models ...
# episode  498 score 24.0 avg_score 30.6
# episode  499 score 14.0 avg_score 30.3
# episode  500 score 32.0 avg_score 30.2
# episode  501 score 63.0 avg_score 30.6
# episode  502 score 14.0 avg_score 30.6
# ... saving models ...
# episode  503 score 37.0 avg_score 30.7
# ... saving models ...
# episode  504 score 42.0 avg_score 30.9
# ... saving models ...
# episode  505 score 24.0 avg_score 31.0
# episode  506 score 20.0 avg_score 31.0
# ... saving models ...
# episode  507 score 86.0 avg_score 31.7
# ... saving models ...
# episode  508 score 49.0 avg_score 31.9
# episode  509 score 100.0 avg_score 31.9
# episode  510 score 18.0 avg_score 31.6
# episode  511 score 30.0 avg_score 31.8
# episode  512 score 19.0 avg_score 31.9
# ... saving models ...
# episode  513 score 29.0 avg_score 32.0
# episode  514 score 23.0 avg_score 31.9
# episode  515 score 29.0 avg_score 32.0
# episode  516 score 8.0 avg_score 31.8
# episode  517 score 24.0 avg_score 31.7
# episode  518 score 19.0 avg_score 31.6
# episode  519 score 10.0 avg_score 31.4
# episode  520 score 49.0 avg_score 31.7
# ... saving models ...
# episode  521 score 96.0 avg_score 32.2
# ... saving models ...
# episode  522 score 28.0 avg_score 32.4
# ... saving models ...
# episode  523 score 31.0 avg_score 32.4
# ... saving models ...
# episode  524 score 38.0 avg_score 32.4
# episode  525 score 15.0 avg_score 31.8
# episode  526 score 15.0 avg_score 31.5
# episode  527 score 17.0 avg_score 31.4
# episode  528 score 19.0 avg_score 31.4
# episode  529 score 70.0 avg_score 31.8
# episode  530 score 17.0 avg_score 31.7
# episode  531 score 31.0 avg_score 31.6
# episode  532 score 22.0 avg_score 31.6
# episode  533 score 24.0 avg_score 31.3
# episode  534 score 17.0 avg_score 31.4
# episode  535 score 20.0 avg_score 31.3
# episode  536 score 30.0 avg_score 31.5
# episode  537 score 87.0 avg_score 32.0
# episode  538 score 32.0 avg_score 32.1
# episode  539 score 38.0 avg_score 32.3
# episode  540 score 27.0 avg_score 32.2
# episode  541 score 25.0 avg_score 32.3
# episode  542 score 21.0 avg_score 32.2
# episode  543 score 59.0 avg_score 32.4
# ... saving models ...
# episode  544 score 42.0 avg_score 32.6
# episode  545 score 21.0 avg_score 32.4
# episode  546 score 33.0 avg_score 32.3
# episode  547 score 23.0 avg_score 32.0
# episode  548 score 58.0 avg_score 32.2
# episode  549 score 56.0 avg_score 32.0
# episode  550 score 16.0 avg_score 31.9
# episode  551 score 42.0 avg_score 32.2
# episode  552 score 29.0 avg_score 32.2
# episode  553 score 15.0 avg_score 32.2
# ... saving models ...
# episode  554 score 73.0 avg_score 32.7
# episode  555 score 14.0 avg_score 32.3
# episode  556 score 26.0 avg_score 32.2
# episode  557 score 27.0 avg_score 32.4
# episode  558 score 28.0 avg_score 32.5
# ... saving models ...
# episode  559 score 47.0 avg_score 32.8
# ... saving models ...
# episode  560 score 112.0 avg_score 33.3
# episode  561 score 15.0 avg_score 33.1
# episode  562 score 26.0 avg_score 33.0
# episode  563 score 36.0 avg_score 32.7
# episode  564 score 48.0 avg_score 33.0
# episode  565 score 45.0 avg_score 33.2
# ... saving models ...
# episode  566 score 50.0 avg_score 33.4
# ... saving models ...
# episode  567 score 21.0 avg_score 33.4
# ... saving models ...
# episode  568 score 48.0 avg_score 33.7
# ... saving models ...
# episode  569 score 41.0 avg_score 33.8
# ... saving models ...
# episode  570 score 98.0 avg_score 34.3
# ... saving models ...
# episode  571 score 30.0 avg_score 34.4
# episode  572 score 11.0 avg_score 34.4
# episode  573 score 15.0 avg_score 34.2
# episode  574 score 17.0 avg_score 34.2
# ... saving models ...
# episode  575 score 50.0 avg_score 34.5
# ... saving models ...
# episode  576 score 77.0 avg_score 34.9
# episode  577 score 23.0 avg_score 34.9
# episode  578 score 16.0 avg_score 34.3
# episode  579 score 52.0 avg_score 34.7
# ... saving models ...
# episode  580 score 46.0 avg_score 35.0
# ... saving models ...
# episode  581 score 51.0 avg_score 35.1
# ... saving models ...
# episode  582 score 30.0 avg_score 35.2
# ... saving models ...
# episode  583 score 34.0 avg_score 35.3
# ... saving models ...
# episode  584 score 35.0 avg_score 35.4
# episode  585 score 16.0 avg_score 35.1
# episode  586 score 34.0 avg_score 35.1
# episode  587 score 38.0 avg_score 35.2
# ... saving models ...
# episode  588 score 43.0 avg_score 35.5
# ... saving models ...
# episode  589 score 38.0 avg_score 35.6
# ... saving models ...
# episode  590 score 43.0 avg_score 35.6
# ... saving models ...
# episode  591 score 20.0 avg_score 35.8
# ... saving models ...
# episode  592 score 40.0 avg_score 35.9
# episode  593 score 15.0 avg_score 35.4
# episode  594 score 32.0 avg_score 35.5
# episode  595 score 33.0 avg_score 35.4
# episode  596 score 55.0 avg_score 35.7
# episode  597 score 10.0 avg_score 35.4
# ... saving models ...
# episode  598 score 83.0 avg_score 36.0
# ... saving models ...
# episode  599 score 65.0 avg_score 36.5
# episode  600 score 19.0 avg_score 36.3
# episode  601 score 63.0 avg_score 36.3
# episode  602 score 15.0 avg_score 36.3
# episode  603 score 29.0 avg_score 36.3
# episode  604 score 32.0 avg_score 36.2
# episode  605 score 23.0 avg_score 36.1
# episode  606 score 42.0 avg_score 36.4
# episode  607 score 61.0 avg_score 36.1
# episode  608 score 22.0 avg_score 35.9
# episode  609 score 22.0 avg_score 35.1
# episode  610 score 36.0 avg_score 35.2
# episode  611 score 23.0 avg_score 35.2
# episode  612 score 52.0 avg_score 35.5
# episode  613 score 51.0 avg_score 35.7
# episode  614 score 29.0 avg_score 35.8
# episode  615 score 17.0 avg_score 35.7
# episode  616 score 30.0 avg_score 35.9
# episode  617 score 25.0 avg_score 35.9
# ... saving models ...
# episode  618 score 94.0 avg_score 36.6
# ... saving models ...
# episode  619 score 24.0 avg_score 36.8
# episode  620 score 24.0 avg_score 36.5
# episode  621 score 29.0 avg_score 35.9
# episode  622 score 71.0 avg_score 36.3
# episode  623 score 26.0 avg_score 36.2
# episode  624 score 47.0 avg_score 36.3
# ... saving models ...
# episode  625 score 92.0 avg_score 37.1
# ... saving models ...
# episode  626 score 78.0 avg_score 37.7
# ... saving models ...
# episode  627 score 37.0 avg_score 37.9
# ... saving models ...
# episode  628 score 41.0 avg_score 38.2
# episode  629 score 60.0 avg_score 38.1
# episode  630 score 27.0 avg_score 38.2
# ... saving models ...
# episode  631 score 92.0 avg_score 38.8
# ... saving models ...
# episode  632 score 26.0 avg_score 38.8
# ... saving models ...
# episode  633 score 32.0 avg_score 38.9
# ... saving models ...
# episode  634 score 26.0 avg_score 39.0
# ... saving models ...
# episode  635 score 91.0 avg_score 39.7
# ... saving models ...
# episode  636 score 72.0 avg_score 40.1
# episode  637 score 50.0 avg_score 39.7
# episode  638 score 60.0 avg_score 40.0
# ... saving models ...
# episode  639 score 49.0 avg_score 40.1
# episode  640 score 21.0 avg_score 40.1
# ... saving models ...
# episode  641 score 46.0 avg_score 40.3
# ... saving models ...
# episode  642 score 35.0 avg_score 40.4
# episode  643 score 24.0 avg_score 40.1
# episode  644 score 73.0 avg_score 40.4
# ... saving models ...
# episode  645 score 41.0 avg_score 40.6
# episode  646 score 33.0 avg_score 40.6
# ... saving models ...
# episode  647 score 55.0 avg_score 40.9
# episode  648 score 40.0 avg_score 40.7
# episode  649 score 56.0 avg_score 40.7
# ... saving models ...
# episode  650 score 55.0 avg_score 41.1
# ... saving models ...
# episode  651 score 104.0 avg_score 41.7
# episode  652 score 27.0 avg_score 41.7
# ... saving models ...
# episode  653 score 27.0 avg_score 41.8
# ... saving models ...
# episode  654 score 77.0 avg_score 41.9
# ... saving models ...
# episode  655 score 26.0 avg_score 42.0
# ... saving models ...
# episode  656 score 65.0 avg_score 42.4
# ... saving models ...
# episode  657 score 68.0 avg_score 42.8
# episode  658 score 18.0 avg_score 42.7
# ... saving models ...
# episode  659 score 65.0 avg_score 42.9
# episode  660 score 67.0 avg_score 42.4
# episode  661 score 28.0 avg_score 42.5
# episode  662 score 52.0 avg_score 42.8
# ... saving models ...
# episode  663 score 46.0 avg_score 42.9
# ... saving models ...
# episode  664 score 59.0 avg_score 43.0
# episode  665 score 34.0 avg_score 42.9
# episode  666 score 42.0 avg_score 42.8
# ... saving models ...
# episode  667 score 54.0 avg_score 43.2
# ... saving models ...
# episode  668 score 76.0 avg_score 43.4
# ... saving models ...
# episode  669 score 51.0 avg_score 43.5
# episode  670 score 33.0 avg_score 42.9
# episode  671 score 33.0 avg_score 42.9
# ... saving models ...
# episode  672 score 117.0 avg_score 44.0
# ... saving models ...
# episode  673 score 50.0 avg_score 44.3
# ... saving models ...
# episode  674 score 19.0 avg_score 44.4
# episode  675 score 32.0 avg_score 44.2
# ... saving models ...
# episode  676 score 99.0 avg_score 44.4
# ... saving models ...
# episode  677 score 60.0 avg_score 44.8
# ... saving models ...
# episode  678 score 59.0 avg_score 45.2
# episode  679 score 26.0 avg_score 44.9
# episode  680 score 60.0 avg_score 45.1
# episode  681 score 39.0 avg_score 45.0
# episode  682 score 29.0 avg_score 44.9
# episode  683 score 42.0 avg_score 45.0
# ... saving models ...
# episode  684 score 77.0 avg_score 45.4
# ... saving models ...
# episode  685 score 46.0 avg_score 45.7
# ... saving models ...
# episode  686 score 58.0 avg_score 46.0
# episode  687 score 38.0 avg_score 46.0
# episode  688 score 34.0 avg_score 45.9
# ... saving models ...
# episode  689 score 55.0 avg_score 46.1
# ... saving models ...
# episode  690 score 74.0 avg_score 46.4
# ... saving models ...
# episode  691 score 42.0 avg_score 46.6
# ... saving models ...
# episode  692 score 55.0 avg_score 46.7
# ... saving models ...
# episode  693 score 77.0 avg_score 47.4
# episode  694 score 20.0 avg_score 47.2
# episode  695 score 17.0 avg_score 47.1
# episode  696 score 44.0 avg_score 47.0
# episode  697 score 30.0 avg_score 47.2
# episode  698 score 90.0 avg_score 47.2
# episode  699 score 25.0 avg_score 46.8
# episode  700 score 62.0 avg_score 47.3
# ... saving models ...
# episode  701 score 73.0 avg_score 47.4
# ... saving models ...
# episode  702 score 42.0 avg_score 47.6
# episode  703 score 29.0 avg_score 47.6
# ... saving models ...
# episode  704 score 86.0 avg_score 48.2
# ... saving models ...
# episode  705 score 57.0 avg_score 48.5
# ... saving models ...
# episode  706 score 52.0 avg_score 48.6
# episode  707 score 39.0 avg_score 48.4
# ... saving models ...
# episode  708 score 45.0 avg_score 48.6
# ... saving models ...
# episode  709 score 40.0 avg_score 48.8
# ... saving models ...
# episode  710 score 38.0 avg_score 48.8
# ... saving models ...
# episode  711 score 148.0 avg_score 50.1
# episode  712 score 48.0 avg_score 50.0
# ... saving models ...
# episode  713 score 79.0 avg_score 50.3
# ... saving models ...
# episode  714 score 40.0 avg_score 50.4
# ... saving models ...
# episode  715 score 29.0 avg_score 50.5
# ... saving models ...
# episode  716 score 70.0 avg_score 51.0
# ... saving models ...
# episode  717 score 79.0 avg_score 51.5
# episode  718 score 45.0 avg_score 51.0
# episode  719 score 39.0 avg_score 51.1
# episode  720 score 54.0 avg_score 51.5
# ... saving models ...
# episode  721 score 47.0 avg_score 51.6
# episode  722 score 47.0 avg_score 51.4
# ... saving models ...
# episode  723 score 56.0 avg_score 51.7
# ... saving models ...
# episode  724 score 72.0 avg_score 51.9
# episode  725 score 33.0 avg_score 51.4
# episode  726 score 63.0 avg_score 51.2
# episode  727 score 33.0 avg_score 51.2
# episode  728 score 72.0 avg_score 51.5
# episode  729 score 50.0 avg_score 51.4
# episode  730 score 56.0 avg_score 51.7
# episode  731 score 34.0 avg_score 51.1
# episode  732 score 87.0 avg_score 51.7
# episode  733 score 25.0 avg_score 51.6
# ... saving models ...
# episode  734 score 116.0 avg_score 52.5
# episode  735 score 85.0 avg_score 52.5
# episode  736 score 41.0 avg_score 52.1
# episode  737 score 59.0 avg_score 52.2
# episode  738 score 78.0 avg_score 52.4
# ... saving models ...
# episode  739 score 72.0 avg_score 52.6
# ... saving models ...
# episode  740 score 60.0 avg_score 53.0
# ... saving models ...
# episode  741 score 65.0 avg_score 53.2
# ... saving models ...
# episode  742 score 55.0 avg_score 53.4
# ... saving models ...
# episode  743 score 27.0 avg_score 53.5
# ... saving models ...
# episode  744 score 78.0 avg_score 53.5
# ... saving models ...
# episode  745 score 46.0 avg_score 53.6
# ... saving models ...
# episode  746 score 67.0 avg_score 53.9
# ... saving models ...
# episode  747 score 72.0 avg_score 54.1
# episode  748 score 35.0 avg_score 54.0
# ... saving models ...
# episode  749 score 68.0 avg_score 54.1
# episode  750 score 42.0 avg_score 54.0
# episode  751 score 54.0 avg_score 53.5
# episode  752 score 52.0 avg_score 53.8
# episode  753 score 65.0 avg_score 54.1
# ... saving models ...
# episode  754 score 88.0 avg_score 54.2
# ... saving models ...
# episode  755 score 66.0 avg_score 54.6
# episode  756 score 44.0 avg_score 54.4
# episode  757 score 70.0 avg_score 54.5
# ... saving models ...
# episode  758 score 62.0 avg_score 54.9
# ... saving models ...
# episode  759 score 87.0 avg_score 55.1
# episode  760 score 65.0 avg_score 55.1
# ... saving models ...
# episode  761 score 53.0 avg_score 55.4
# ... saving models ...
# episode  762 score 113.0 avg_score 56.0
# episode  763 score 22.0 avg_score 55.7
# ... saving models ...
# episode  764 score 159.0 avg_score 56.7
# ... saving models ...
# episode  765 score 87.0 avg_score 57.2
# episode  766 score 25.0 avg_score 57.1
# episode  767 score 33.0 avg_score 56.9
# episode  768 score 88.0 avg_score 57.0
# episode  769 score 49.0 avg_score 57.0
# ... saving models ...
# episode  770 score 70.0 avg_score 57.3
# ... saving models ...
# episode  771 score 60.0 avg_score 57.6
# ... saving models ...
# episode  772 score 192.0 avg_score 58.4
# episode  773 score 47.0 avg_score 58.3
# ... saving models ...
# episode  774 score 95.0 avg_score 59.1
# ... saving models ...
# episode  775 score 40.0 avg_score 59.2
# episode  776 score 43.0 avg_score 58.6
# episode  777 score 82.0 avg_score 58.8
# episode  778 score 87.0 avg_score 59.1
# ... saving models ...
# episode  779 score 79.0 avg_score 59.6
# ... saving models ...
# episode  780 score 85.0 avg_score 59.9
# ... saving models ...
# episode  781 score 76.0 avg_score 60.3
# ... saving models ...
# episode  782 score 58.0 avg_score 60.5
# ... saving models ...
# episode  783 score 89.0 avg_score 61.0
# ... saving models ...
# episode  784 score 88.0 avg_score 61.1
# ... saving models ...
# episode  785 score 85.0 avg_score 61.5
# episode  786 score 49.0 avg_score 61.4
# ... saving models ...
# episode  787 score 58.0 avg_score 61.6
# ... saving models ...
# episode  788 score 67.0 avg_score 62.0
# episode  789 score 49.0 avg_score 61.9
# ... saving models ...
# episode  790 score 104.0 avg_score 62.2
# ... saving models ...
# episode  791 score 123.0 avg_score 63.0
# ... saving models ...
# episode  792 score 77.0 avg_score 63.2
# ... saving models ...
# episode  793 score 101.0 avg_score 63.5
# ... saving models ...
# episode  794 score 82.0 avg_score 64.1
# ... saving models ...
# episode  795 score 61.0 avg_score 64.5
# ... saving models ...
# episode  796 score 87.0 avg_score 65.0
# ... saving models ...
# episode  797 score 76.0 avg_score 65.4
# episode  798 score 89.0 avg_score 65.4
# ... saving models ...
# episode  799 score 62.0 avg_score 65.8
# ... saving models ...
# episode  800 score 156.0 avg_score 66.7
# ... saving models ...
# episode  801 score 95.0 avg_score 66.9
# ... saving models ...
# episode  802 score 82.0 avg_score 67.3
# ... saving models ...
# episode  803 score 167.0 avg_score 68.7
# episode  804 score 70.0 avg_score 68.6
# ... saving models ...
# episode  805 score 110.0 avg_score 69.1
# ... saving models ...
# episode  806 score 65.0 avg_score 69.2
# ... saving models ...
# episode  807 score 43.0 avg_score 69.3
# ... saving models ...
# episode  808 score 54.0 avg_score 69.3
# ... saving models ...
# episode  809 score 75.0 avg_score 69.7
# ... saving models ...
# episode  810 score 51.0 avg_score 69.8
# episode  811 score 59.0 avg_score 68.9
# episode  812 score 43.0 avg_score 68.9
# ... saving models ...
# episode  813 score 200.0 avg_score 70.1
# ... saving models ...
# episode  814 score 132.0 avg_score 71.0
# ... saving models ...
# episode  815 score 72.0 avg_score 71.5
# ... saving models ...
# episode  816 score 89.0 avg_score 71.6
# ... saving models ...
# episode  817 score 96.0 avg_score 71.8
# ... saving models ...
# episode  818 score 123.0 avg_score 72.6
# ... saving models ...
# episode  819 score 47.0 avg_score 72.7
# ... saving models ...
# episode  820 score 200.0 avg_score 74.1
# ... saving models ...
# episode  821 score 58.0 avg_score 74.2
# ... saving models ...
# episode  822 score 81.0 avg_score 74.6
# ... saving models ...
# episode  823 score 70.0 avg_score 74.7
# ... saving models ...
# episode  824 score 105.0 avg_score 75.0
# ... saving models ...
# episode  825 score 47.0 avg_score 75.2
# ... saving models ...
# episode  826 score 143.0 avg_score 76.0
# ... saving models ...
# episode  827 score 69.0 avg_score 76.3
# episode  828 score 54.0 avg_score 76.2
# ... saving models ...
# episode  829 score 107.0 avg_score 76.7
# ... saving models ...
# episode  830 score 61.0 avg_score 76.8
# ... saving models ...
# episode  831 score 78.0 avg_score 77.2
# ... saving models ...
# episode  832 score 150.0 avg_score 77.9
# ... saving models ...
# episode  833 score 91.0 avg_score 78.5
# episode  834 score 59.0 avg_score 78.0
# episode  835 score 70.0 avg_score 77.8
# episode  836 score 74.0 avg_score 78.1
# episode  837 score 54.0 avg_score 78.1
# ... saving models ...
# episode  838 score 126.0 avg_score 78.6
# episode  839 score 49.0 avg_score 78.3
# episode  840 score 77.0 avg_score 78.5
# episode  841 score 62.0 avg_score 78.5
# ... saving models ...
# episode  842 score 89.0 avg_score 78.8
# ... saving models ...
# episode  843 score 137.0 avg_score 79.9
# ... saving models ...
# episode  844 score 106.0 avg_score 80.2
# ... saving models ...
# episode  845 score 115.0 avg_score 80.9
# episode  846 score 66.0 avg_score 80.9
# ... saving models ...
# episode  847 score 81.0 avg_score 81.0
# ... saving models ...
# episode  848 score 84.0 avg_score 81.5
# ... saving models ...
# episode  849 score 71.0 avg_score 81.5
# ... saving models ...
# episode  850 score 66.0 avg_score 81.7
# ... saving models ...
# episode  851 score 67.0 avg_score 81.8
# ... saving models ...
# episode  852 score 59.0 avg_score 81.9
# ... saving models ...
# episode  853 score 112.0 avg_score 82.4
# episode  854 score 77.0 avg_score 82.3
# episode  855 score 70.0 avg_score 82.3
# ... saving models ...
# episode  856 score 126.0 avg_score 83.1
# ... saving models ...
# episode  857 score 91.0 avg_score 83.3
# ... saving models ...
# episode  858 score 200.0 avg_score 84.7
# episode  859 score 66.0 avg_score 84.5
# episode  860 score 60.0 avg_score 84.5
# episode  861 score 60.0 avg_score 84.5
# ... saving models ...
# episode  862 score 143.0 avg_score 84.8
# ... saving models ...
# episode  863 score 52.0 avg_score 85.1
# episode  864 score 80.0 avg_score 84.3
# episode  865 score 86.0 avg_score 84.3
# ... saving models ...
# episode  866 score 157.0 avg_score 85.7
# ... saving models ...
# episode  867 score 137.0 avg_score 86.7
# episode  868 score 73.0 avg_score 86.5
# ... saving models ...
# episode  869 score 190.0 avg_score 88.0
# episode  870 score 67.0 avg_score 87.9
# episode  871 score 55.0 avg_score 87.9
# episode  872 score 130.0 avg_score 87.3
# episode  873 score 74.0 avg_score 87.5
# episode  874 score 78.0 avg_score 87.4
# episode  875 score 80.0 avg_score 87.8
# ... saving models ...
# episode  876 score 90.0 avg_score 88.2
# episode  877 score 73.0 avg_score 88.1
# episode  878 score 46.0 avg_score 87.7
# episode  879 score 79.0 avg_score 87.7
# episode  880 score 127.0 avg_score 88.2
# episode  881 score 50.0 avg_score 87.9
# episode  882 score 59.0 avg_score 87.9
# episode  883 score 57.0 avg_score 87.6
# episode  884 score 86.0 avg_score 87.6
# ... saving models ...
# episode  885 score 191.0 avg_score 88.6
# ... saving models ...
# episode  886 score 68.0 avg_score 88.8
# ... saving models ...
# episode  887 score 88.0 avg_score 89.1
# ... saving models ...
# episode  888 score 101.0 avg_score 89.5
# ... saving models ...
# episode  889 score 79.0 avg_score 89.8
# episode  890 score 86.0 avg_score 89.6
# episode  891 score 53.0 avg_score 88.9
# episode  892 score 67.0 avg_score 88.8
# episode  893 score 70.0 avg_score 88.5
# episode  894 score 152.0 avg_score 89.2
# episode  895 score 78.0 avg_score 89.3
# episode  896 score 70.0 avg_score 89.2
# episode  897 score 49.0 avg_score 88.9
# episode  898 score 66.0 avg_score 88.7
# episode  899 score 97.0 avg_score 89.0
# episode  900 score 171.0 avg_score 89.2
# ... saving models ...
# episode  901 score 166.0 avg_score 89.9
# ... saving models ...
# episode  902 score 170.0 avg_score 90.8
# episode  903 score 65.0 avg_score 89.7
# episode  904 score 69.0 avg_score 89.7
# episode  905 score 83.0 avg_score 89.5
# episode  906 score 36.0 avg_score 89.2
# episode  907 score 54.0 avg_score 89.3
# episode  908 score 180.0 avg_score 90.5
# episode  909 score 60.0 avg_score 90.4
# ... saving models ...
# episode  910 score 143.0 avg_score 91.3
# ... saving models ...
# episode  911 score 80.0 avg_score 91.5
# ... saving models ...
# episode  912 score 69.0 avg_score 91.8
# episode  913 score 70.0 avg_score 90.5
# episode  914 score 83.0 avg_score 90.0
# episode  915 score 151.0 avg_score 90.8
# episode  916 score 75.0 avg_score 90.6
# episode  917 score 96.0 avg_score 90.6
# episode  918 score 82.0 avg_score 90.2
# episode  919 score 136.0 avg_score 91.1
# episode  920 score 74.0 avg_score 89.8
# episode  921 score 88.0 avg_score 90.2
# episode  922 score 200.0 avg_score 91.3
# episode  923 score 47.0 avg_score 91.1
# episode  924 score 62.0 avg_score 90.7
# episode  925 score 53.0 avg_score 90.7
# episode  926 score 75.0 avg_score 90.1
# episode  927 score 44.0 avg_score 89.8
# episode  928 score 48.0 avg_score 89.8
# episode  929 score 58.0 avg_score 89.3
# episode  930 score 78.0 avg_score 89.4
# episode  931 score 46.0 avg_score 89.1
# episode  932 score 54.0 avg_score 88.2
# episode  933 score 107.0 avg_score 88.3
# episode  934 score 57.0 avg_score 88.3
# episode  935 score 43.0 avg_score 88.0
# episode  936 score 62.0 avg_score 87.9
# episode  937 score 52.0 avg_score 87.9
# episode  938 score 62.0 avg_score 87.2
# episode  939 score 61.0 avg_score 87.4
# episode  940 score 82.0 avg_score 87.4
# episode  941 score 45.0 avg_score 87.2
# episode  942 score 104.0 avg_score 87.4
# episode  943 score 183.0 avg_score 87.8
# episode  944 score 65.0 avg_score 87.4
# episode  945 score 60.0 avg_score 86.9
# episode  946 score 200.0 avg_score 88.2
# episode  947 score 48.0 avg_score 87.9
# episode  948 score 82.0 avg_score 87.9
# episode  949 score 59.0 avg_score 87.8
# episode  950 score 93.0 avg_score 88.0
# episode  951 score 62.0 avg_score 88.0
# episode  952 score 154.0 avg_score 88.9
# episode  953 score 48.0 avg_score 88.3
# episode  954 score 68.0 avg_score 88.2
# episode  955 score 94.0 avg_score 88.4
# episode  956 score 82.0 avg_score 88.0
# episode  957 score 190.0 avg_score 89.0
# episode  958 score 200.0 avg_score 89.0
# episode  959 score 78.0 avg_score 89.1
# episode  960 score 39.0 avg_score 88.9
# episode  961 score 80.0 avg_score 89.1
# episode  962 score 114.0 avg_score 88.8
# episode  963 score 91.0 avg_score 89.2
# episode  964 score 78.0 avg_score 89.2
# episode  965 score 79.0 avg_score 89.1
# episode  966 score 58.0 avg_score 88.1
# episode  967 score 99.0 avg_score 87.7
# episode  968 score 68.0 avg_score 87.7
# episode  969 score 115.0 avg_score 86.9
# episode  970 score 200.0 avg_score 88.3
# episode  971 score 125.0 avg_score 89.0
# episode  972 score 73.0 avg_score 88.4
# episode  973 score 163.0 avg_score 89.3
# episode  974 score 131.0 avg_score 89.8
# episode  975 score 54.0 avg_score 89.6
# episode  976 score 113.0 avg_score 89.8
# episode  977 score 74.0 avg_score 89.8
# episode  978 score 49.0 avg_score 89.8
# episode  979 score 52.0 avg_score 89.6
# episode  980 score 97.0 avg_score 89.3
# episode  981 score 82.0 avg_score 89.6
# episode  982 score 77.0 avg_score 89.8
# episode  983 score 79.0 avg_score 90.0
# episode  984 score 161.0 avg_score 90.7
# episode  985 score 95.0 avg_score 89.8
# episode  986 score 103.0 avg_score 90.1
# episode  987 score 73.0 avg_score 90.0
# episode  988 score 67.0 avg_score 89.6
# episode  989 score 66.0 avg_score 89.5
# episode  990 score 108.0 avg_score 89.7
# episode  991 score 197.0 avg_score 91.2
# episode  992 score 52.0 avg_score 91.0
# episode  993 score 54.0 avg_score 90.8
# episode  994 score 61.0 avg_score 89.9
# episode  995 score 151.0 avg_score 90.7
# episode  996 score 143.0 avg_score 91.4
# ... saving models ...
# episode  997 score 172.0 avg_score 92.6
# episode  998 score 48.0 avg_score 92.5
# episode  999 score 68.0 avg_score 92.2
# episode  1000 score 61.0 avg_score 91.1
# episode  1001 score 96.0 avg_score 90.4
# episode  1002 score 114.0 avg_score 89.8
# episode  1003 score 46.0 avg_score 89.6
# episode  1004 score 62.0 avg_score 89.5
# episode  1005 score 109.0 avg_score 89.8
# episode  1006 score 93.0 avg_score 90.4
# episode  1007 score 103.0 avg_score 90.9
# episode  1008 score 59.0 avg_score 89.7
# episode  1009 score 136.0 avg_score 90.4
# episode  1010 score 90.0 avg_score 89.9
# episode  1011 score 67.0 avg_score 89.8
# episode  1012 score 151.0 avg_score 90.6
# episode  1013 score 116.0 avg_score 91.0
# episode  1014 score 55.0 avg_score 90.8
# episode  1015 score 71.0 avg_score 90.0
# episode  1016 score 160.0 avg_score 90.8
# episode  1017 score 131.0 avg_score 91.2
# episode  1018 score 65.0 avg_score 91.0
# episode  1019 score 200.0 avg_score 91.6
# episode  1020 score 68.0 avg_score 91.6
# episode  1021 score 96.0 avg_score 91.6
# episode  1022 score 53.0 avg_score 90.2
# episode  1023 score 89.0 avg_score 90.6
# episode  1024 score 56.0 avg_score 90.5
# episode  1025 score 162.0 avg_score 91.6
# episode  1026 score 85.0 avg_score 91.7
# episode  1027 score 69.0 avg_score 92.0
# ... saving models ...
# episode  1028 score 152.0 avg_score 93.0
# ... saving models ...
# episode  1029 score 120.0 avg_score 93.6
# ... saving models ...
# episode  1030 score 85.0 avg_score 93.7
# ... saving models ...
# episode  1031 score 100.0 avg_score 94.2
# ... saving models ...
# episode  1032 score 126.0 avg_score 95.0
# ... saving models ...
# episode  1033 score 109.0 avg_score 95.0
# ... saving models ...
# episode  1034 score 65.0 avg_score 95.1
# ... saving models ...
# episode  1035 score 84.0 avg_score 95.5
# ... saving models ...
# episode  1036 score 77.0 avg_score 95.6
# ... saving models ...
# episode  1037 score 89.0 avg_score 96.0
# ... saving models ...
# episode  1038 score 86.0 avg_score 96.2
# ... saving models ...
# episode  1039 score 98.0 avg_score 96.6
# ... saving models ...
# episode  1040 score 114.0 avg_score 96.9
# ... saving models ...
# episode  1041 score 59.0 avg_score 97.1
# ... saving models ...
# episode  1042 score 149.0 avg_score 97.5
# episode  1043 score 145.0 avg_score 97.1
# ... saving models ...
# episode  1044 score 131.0 avg_score 97.8
# ... saving models ...
# episode  1045 score 92.0 avg_score 98.1
# episode  1046 score 110.0 avg_score 97.2
# episode  1047 score 100.0 avg_score 97.7
# episode  1048 score 71.0 avg_score 97.6
# episode  1049 score 55.0 avg_score 97.6
# episode  1050 score 63.0 avg_score 97.3
# episode  1051 score 124.0 avg_score 97.9
# episode  1052 score 81.0 avg_score 97.2
# episode  1053 score 66.0 avg_score 97.3
# episode  1054 score 67.0 avg_score 97.3
# episode  1055 score 81.0 avg_score 97.2
# episode  1056 score 83.0 avg_score 97.2
# episode  1057 score 189.0 avg_score 97.2
# episode  1058 score 72.0 avg_score 95.9
# episode  1059 score 63.0 avg_score 95.8
# episode  1060 score 62.0 avg_score 96.0
# episode  1061 score 129.0 avg_score 96.5
# episode  1062 score 78.0 avg_score 96.1
# episode  1063 score 200.0 avg_score 97.2
# episode  1064 score 93.0 avg_score 97.4
# ... saving models ...
# ...
# episode  1479 score 98.0 avg_score 113.9
# episode  1480 score 135.0 avg_score 114.2
# episode  1481 score 133.0 avg_score 114.5
# episode  1482 score 91.0 avg_score 113.5
# episode  1483 score 76.0 avg_score 112.9
# episode  1484 score 68.0 avg_score 112.6
# episode  1485 score 113.0 avg_score 112.8
# episode  1486 score 179.0 avg_score 113.2
# episode  1487 score 114.0 avg_score 112.9
# episode  1488 score 85.0 avg_score 112.5
# episode  1489 score 200.0 avg_score 113.7
# episode  1490 score 88.0 avg_score 113.6
# episode  1491 score 104.0 avg_score 113.4
# episode  1492 score 79.0 avg_score 113.5
# episode  1493 score 103.0 avg_score 113.6
# episode  1494 score 88.0 avg_score 112.9
# episode  1495 score 94.0 avg_score 112.7
# episode  1496 score 101.0 avg_score 111.7
# episode  1497 score 141.0 avg_score 112.1
# episode  1498 score 107.0 avg_score 111.2
# episode  1499 score 155.0 avg_score 111.8
# episode  1500 score 161.0 avg_score 112.1
# episode  1501 score 94.0 avg_score 112.0
# episode  1502 score 101.0 avg_score 112.0
# episode  1503 score 200.0 avg_score 112.6
# episode  1504 score 91.0 avg_score 112.5
# episode  1505 score 200.0 avg_score 113.4
# episode  1506 score 86.0 avg_score 113.4
# episode  1507 score 200.0 avg_score 114.4
# episode  1508 score 99.0 avg_score 114.2
# episode  1509 score 75.0 avg_score 114.2
# episode  1510 score 194.0 avg_score 115.2
# episode  1511 score 69.0 avg_score 114.8
# episode  1512 score 97.0 avg_score 114.9
# episode  1513 score 102.0 avg_score 114.0
# episode  1514 score 122.0 avg_score 113.7
# episode  1515 score 129.0 avg_score 114.2
# episode  1516 score 114.0 avg_score 113.8
# episode  1517 score 98.0 avg_score 113.1
# episode  1518 score 103.0 avg_score 112.9
# episode  1519 score 146.0 avg_score 113.2
# episode  1520 score 90.0 avg_score 112.8
# episode  1521 score 112.0 avg_score 112.0
# episode  1522 score 109.0 avg_score 112.1
# episode  1523 score 83.0 avg_score 111.5
# episode  1524 score 106.0 avg_score 111.9
# episode  1525 score 130.0 avg_score 112.5
# episode  1526 score 105.0 avg_score 112.4
# episode  1527 score 132.0 avg_score 112.2
# episode  1528 score 71.0 avg_score 111.6
# episode  1529 score 101.0 avg_score 111.6
# episode  1530 score 132.0 avg_score 111.7
# episode  1531 score 83.0 avg_score 110.5
# episode  1532 score 94.0 avg_score 110.6
# episode  1533 score 83.0 avg_score 110.5
# episode  1534 score 103.0 avg_score 110.5
# episode  1535 score 67.0 avg_score 110.1
# episode  1536 score 196.0 avg_score 111.2
# episode  1537 score 135.0 avg_score 111.6
# episode  1538 score 97.0 avg_score 111.6
# episode  1539 score 107.0 avg_score 112.0
# episode  1540 score 108.0 avg_score 112.2
# episode  1541 score 73.0 avg_score 112.1
# episode  1542 score 91.0 avg_score 112.1
# episode  1543 score 92.0 avg_score 111.5
# episode  1544 score 200.0 avg_score 112.6
# episode  1545 score 200.0 avg_score 113.7
# episode  1546 score 117.0 avg_score 113.9
# episode  1547 score 95.0 avg_score 114.2
# episode  1548 score 124.0 avg_score 114.4
# episode  1549 score 200.0 avg_score 115.4
# episode  1550 score 127.0 avg_score 115.6
# episode  1551 score 116.0 avg_score 114.8
# episode  1552 score 130.0 avg_score 114.8
# episode  1553 score 121.0 avg_score 115.2
# episode  1554 score 93.0 avg_score 115.1
# episode  1555 score 200.0 avg_score 115.5
# episode  1556 score 130.0 avg_score 116.0
# episode  1557 score 154.0 avg_score 116.5
# episode  1558 score 147.0 avg_score 116.7
# episode  1559 score 164.0 avg_score 117.6
# episode  1560 score 161.0 avg_score 118.5
# episode  1561 score 140.0 avg_score 118.8
# episode  1562 score 88.0 avg_score 118.8
# episode  1563 score 200.0 avg_score 119.6
# episode  1564 score 165.0 avg_score 120.2
# episode  1565 score 97.0 avg_score 119.7
# episode  1566 score 109.0 avg_score 119.7
# episode  1567 score 197.0 avg_score 120.2
# episode  1568 score 114.0 avg_score 120.5
# episode  1569 score 90.0 avg_score 120.2
# episode  1570 score 153.0 avg_score 121.0
# episode  1571 score 152.0 avg_score 121.6
# episode  1572 score 177.0 avg_score 122.5
# episode  1573 score 115.0 avg_score 121.7
# episode  1574 score 106.0 avg_score 121.5
# episode  1575 score 109.0 avg_score 121.8
# episode  1576 score 200.0 avg_score 122.9
# ... saving models ...
# episode  1577 score 179.0 avg_score 123.9
# episode  1578 score 155.0 avg_score 123.6
# episode  1579 score 117.0 avg_score 123.8
# episode  1580 score 132.0 avg_score 123.7
# episode  1581 score 134.0 avg_score 123.8
# ... saving models ...
# episode  1582 score 172.0 avg_score 124.6
# ... saving models ...
# episode  1583 score 99.0 avg_score 124.8
# ... saving models ...
# episode  1584 score 117.0 avg_score 125.3
# ... saving models ...
# episode  1585 score 200.0 avg_score 126.2
# episode  1586 score 114.0 avg_score 125.5
# episode  1587 score 88.0 avg_score 125.2
# episode  1588 score 74.0 avg_score 125.1
# episode  1589 score 106.0 avg_score 124.2
# episode  1590 score 116.0 avg_score 124.5
# episode  1591 score 117.0 avg_score 124.6
# episode  1592 score 159.0 avg_score 125.4
# episode  1593 score 86.0 avg_score 125.2
# episode  1594 score 136.0 avg_score 125.7
# episode  1595 score 109.0 avg_score 125.9
# episode  1596 score 126.0 avg_score 126.1
# episode  1597 score 93.0 avg_score 125.6
# episode  1598 score 97.0 avg_score 125.5
# episode  1599 score 129.0 avg_score 125.3
# episode  1600 score 110.0 avg_score 124.8
# episode  1601 score 87.0 avg_score 124.7
# episode  1602 score 105.0 avg_score 124.7
# episode  1603 score 147.0 avg_score 124.2
# episode  1604 score 120.0 avg_score 124.5
# episode  1605 score 79.0 avg_score 123.3
# episode  1606 score 195.0 avg_score 124.4
# episode  1607 score 126.0 avg_score 123.6
# episode  1608 score 125.0 avg_score 123.9
# episode  1609 score 192.0 avg_score 125.1
# episode  1610 score 200.0 avg_score 125.1
# ... saving models ...
# episode  1611 score 199.0 avg_score 126.4
# ... saving models ...
# episode  1612 score 148.0 avg_score 126.9
# ... saving models ...
# episode  1613 score 111.0 avg_score 127.0
# episode  1614 score 81.0 avg_score 126.6
# ... saving models ...
# episode  1615 score 196.0 avg_score 127.3
# episode  1616 score 110.0 avg_score 127.2
# episode  1617 score 101.0 avg_score 127.3
# episode  1618 score 80.0 avg_score 127.0
# episode  1619 score 115.0 avg_score 126.7
# ... saving models ...
# episode  1620 score 160.0 avg_score 127.4
# ... saving models ...
# episode  1621 score 139.0 avg_score 127.7
# ... saving models ...
# episode  1622 score 122.0 avg_score 127.8
# ... saving models ...
# episode  1623 score 116.0 avg_score 128.2
# ... saving models ...
# episode  1624 score 146.0 avg_score 128.6
# ... saving models ...
# episode  1625 score 137.0 avg_score 128.6
# episode  1626 score 77.0 avg_score 128.3
# episode  1627 score 129.0 avg_score 128.3
# ... saving models ...
# episode  1628 score 178.0 avg_score 129.4
# ... saving models ...
# episode  1629 score 131.0 avg_score 129.7
# ... saving models ...
# episode  1630 score 200.0 avg_score 130.4
# ... saving models ...
# episode  1631 score 134.0 avg_score 130.9
# episode  1632 score 90.0 avg_score 130.8
# ... saving models ...
# episode  1633 score 131.0 avg_score 131.3
# ... saving models ...
# episode  1634 score 111.0 avg_score 131.4
# ... saving models ...
# episode  1635 score 80.0 avg_score 131.5
# episode  1636 score 113.0 avg_score 130.7
# episode  1637 score 200.0 avg_score 131.3
# ... saving models ...
# episode  1638 score 133.0 avg_score 131.7
# episode  1639 score 80.0 avg_score 131.4
# episode  1640 score 121.0 avg_score 131.6
# ... saving models ...
# episode  1641 score 100.0 avg_score 131.8
# ... saving models ...
# episode  1642 score 140.0 avg_score 132.3
# ... saving models ...
# episode  1643 score 127.0 avg_score 132.7
# episode  1644 score 141.0 avg_score 132.1
# episode  1645 score 98.0 avg_score 131.1
# episode  1646 score 156.0 avg_score 131.5
# episode  1647 score 132.0 avg_score 131.8
# episode  1648 score 97.0 avg_score 131.6
# episode  1649 score 200.0 avg_score 131.6
# episode  1650 score 173.0 avg_score 132.0
# ... saving models ...
# episode  1651 score 199.0 avg_score 132.8
# episode  1652 score 124.0 avg_score 132.8
# episode  1653 score 119.0 avg_score 132.8
# ... saving models ...
# episode  1654 score 200.0 avg_score 133.8
# episode  1655 score 200.0 avg_score 133.8
# ... saving models ...
# episode  1656 score 136.0 avg_score 133.9
# episode  1657 score 136.0 avg_score 133.7
# ... saving models ...
# episode  1658 score 167.0 avg_score 133.9
# ... saving models ...
# episode  1659 score 187.0 avg_score 134.2
# episode  1660 score 156.0 avg_score 134.1
# ... saving models ...
# episode  1661 score 195.0 avg_score 134.7
# ... saving models ...
# episode  1662 score 200.0 avg_score 135.8
# episode  1663 score 139.0 avg_score 135.2
# episode  1664 score 105.0 avg_score 134.6
# episode  1665 score 160.0 avg_score 135.2
# episode  1666 score 166.0 avg_score 135.8
# episode  1667 score 124.0 avg_score 135.0
# episode  1668 score 187.0 avg_score 135.8
# ... saving models ...
# episode  1669 score 165.0 avg_score 136.5
# episode  1670 score 105.0 avg_score 136.0
# episode  1671 score 160.0 avg_score 136.1
# episode  1672 score 194.0 avg_score 136.3
# ... saving models ...
# episode  1673 score 148.0 avg_score 136.6
# ... saving models ...
# episode  1674 score 120.0 avg_score 136.8
# ... saving models ...
# episode  1675 score 200.0 avg_score 137.7
# episode  1676 score 178.0 avg_score 137.4
# episode  1677 score 120.0 avg_score 136.8
# episode  1678 score 195.0 avg_score 137.2
# ... saving models ...
# episode  1679 score 179.0 avg_score 137.9
# ... saving models ...
# episode  1680 score 195.0 avg_score 138.5
# ... saving models ...
# episode  1681 score 164.0 avg_score 138.8
# episode  1682 score 164.0 avg_score 138.7
# episode  1683 score 104.0 avg_score 138.8
# episode  1684 score 95.0 avg_score 138.6
# episode  1685 score 144.0 avg_score 138.0
# episode  1686 score 163.0 avg_score 138.5
# ... saving models ...
# episode  1687 score 176.0 avg_score 139.4
# ... saving models ...
# episode  1688 score 193.0 avg_score 140.6
# ... saving models ...
# episode  1689 score 164.0 avg_score 141.1
# ... saving models ...
# episode  1690 score 144.0 avg_score 141.4
# ... saving models ...
# episode  1691 score 186.0 avg_score 142.1
# ... saving models ...
# episode  1692 score 192.0 avg_score 142.4
# ... saving models ...
# episode  1693 score 94.0 avg_score 142.5
# episode  1694 score 82.0 avg_score 142.0
# ... saving models ...
# episode  1695 score 169.0 avg_score 142.6
# ... saving models ...
# episode  1696 score 200.0 avg_score 143.3
# ... saving models ...
# episode  1697 score 119.0 avg_score 143.6
# ... saving models ...
# episode  1698 score 163.0 avg_score 144.2
# ... saving models ...
# episode  1699 score 137.0 avg_score 144.3
# episode  1700 score 104.0 avg_score 144.2
# ... saving models ...
# episode  1701 score 102.0 avg_score 144.4
# ... saving models ...
# episode  1702 score 124.0 avg_score 144.6
# ... saving models ...
# episode  1703 score 200.0 avg_score 145.1
# episode  1704 score 107.0 avg_score 145.0
# ... saving models ...
# episode  1705 score 200.0 avg_score 146.2
# episode  1706 score 123.0 avg_score 145.5
# episode  1707 score 97.0 avg_score 145.2
# episode  1708 score 110.0 avg_score 145.0
# episode  1709 score 171.0 avg_score 144.8
# episode  1710 score 200.0 avg_score 144.8
# episode  1711 score 168.0 avg_score 144.5
# episode  1712 score 110.0 avg_score 144.1
# episode  1713 score 96.0 avg_score 144.0
# episode  1714 score 117.0 avg_score 144.3
# episode  1715 score 103.0 avg_score 143.4
# episode  1716 score 140.0 avg_score 143.7
# episode  1717 score 200.0 avg_score 144.7
# episode  1718 score 184.0 avg_score 145.8
# episode  1719 score 99.0 avg_score 145.6
# episode  1720 score 189.0 avg_score 145.9
# episode  1721 score 112.0 avg_score 145.6
# episode  1722 score 122.0 avg_score 145.6
# ... saving models ...
# episode  1723 score 200.0 avg_score 146.4
# episode  1724 score 120.0 avg_score 146.2
# ... saving models ...
# episode  1725 score 200.0 avg_score 146.8
# ... saving models ...
# episode  1726 score 184.0 avg_score 147.9
# ... saving models ...
# episode  1727 score 172.0 avg_score 148.3
# ... saving models ...
# episode  1728 score 200.0 avg_score 148.5
# ... saving models ...
# episode  1729 score 158.0 avg_score 148.8
# episode  1730 score 106.0 avg_score 147.9
# episode  1731 score 200.0 avg_score 148.5
# ... saving models ...
# episode  1732 score 177.0 avg_score 149.4
# episode  1733 score 114.0 avg_score 149.2
# ... saving models ...
# episode  1734 score 135.0 avg_score 149.5
# ... saving models ...
# episode  1735 score 200.0 avg_score 150.7
# ... saving models ...
# episode  1736 score 200.0 avg_score 151.5
# episode  1737 score 200.0 avg_score 151.5
# ... saving models ...
# episode  1738 score 157.0 avg_score 151.8
# ... saving models ...
# episode  1739 score 158.0 avg_score 152.6
# ... saving models ...
# episode  1740 score 129.0 avg_score 152.6
# ... saving models ...
# episode  1741 score 120.0 avg_score 152.8
# ... saving models ...
# episode  1742 score 181.0 avg_score 153.2
# ... saving models ...
# episode  1743 score 135.0 avg_score 153.3
# episode  1744 score 127.0 avg_score 153.2
# ... saving models ...
# episode  1745 score 196.0 avg_score 154.2
# ... saving models ...
# episode  1746 score 189.0 avg_score 154.5
# episode  1747 score 113.0 avg_score 154.3
# episode  1748 score 112.0 avg_score 154.5
# episode  1749 score 118.0 avg_score 153.6
# episode  1750 score 154.0 avg_score 153.4
# episode  1751 score 165.0 avg_score 153.1
# episode  1752 score 144.0 avg_score 153.3
# episode  1753 score 151.0 avg_score 153.6
# episode  1754 score 155.0 avg_score 153.2
# episode  1755 score 196.0 avg_score 153.1
# episode  1756 score 200.0 avg_score 153.8
# episode  1757 score 129.0 avg_score 153.7
# episode  1758 score 124.0 avg_score 153.3
# episode  1759 score 153.0 avg_score 152.9
# episode  1760 score 120.0 avg_score 152.6
# episode  1761 score 135.0 avg_score 152.0
# episode  1762 score 163.0 avg_score 151.6
# episode  1763 score 158.0 avg_score 151.8
# episode  1764 score 197.0 avg_score 152.7
# episode  1765 score 200.0 avg_score 153.1
# episode  1766 score 200.0 avg_score 153.5
# episode  1767 score 159.0 avg_score 153.8
# episode  1768 score 133.0 avg_score 153.3
# episode  1769 score 200.0 avg_score 153.6
# episode  1770 score 126.0 avg_score 153.8
# episode  1771 score 200.0 avg_score 154.2
# episode  1772 score 148.0 avg_score 153.8
# episode  1773 score 192.0 avg_score 154.2
# ... saving models ...
# episode  1774 score 165.0 avg_score 154.7
# episode  1775 score 194.0 avg_score 154.6
# episode  1776 score 115.0 avg_score 154.0
# episode  1777 score 154.0 avg_score 154.3
# episode  1778 score 200.0 avg_score 154.4
# episode  1779 score 189.0 avg_score 154.5
# episode  1780 score 177.0 avg_score 154.3
# episode  1781 score 200.0 avg_score 154.6
# episode  1782 score 125.0 avg_score 154.2
# episode  1783 score 143.0 avg_score 154.6
# ... saving models ...
# episode  1784 score 145.0 avg_score 155.1
# episode  1785 score 142.0 avg_score 155.1
# episode  1786 score 159.0 avg_score 155.1
# ... saving models ...
# episode  1787 score 200.0 avg_score 155.3
# episode  1788 score 166.0 avg_score 155.1
# episode  1789 score 132.0 avg_score 154.7
# episode  1790 score 200.0 avg_score 155.3
# episode  1791 score 182.0 avg_score 155.2
# episode  1792 score 143.0 avg_score 154.8
# ... saving models ...
# episode  1793 score 172.0 avg_score 155.5
# ... saving models ...
# episode  1794 score 200.0 avg_score 156.7
# ... saving models ...
# episode  1795 score 197.0 avg_score 157.0
# episode  1796 score 191.0 avg_score 156.9
# ... saving models ...
# episode  1797 score 200.0 avg_score 157.7
# ... saving models ...
# episode  1798 score 200.0 avg_score 158.1
# ... saving models ...
# episode  1799 score 155.0 avg_score 158.3
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-16-8f727dea3b5a> in <cell line: 0>()
#      50     if not load_checkpoint:
#      51         x = [i+1 for i in range(n_games)]
# ---> 52         plot_learning_curve(x, score_history, figure_file)
#
# <ipython-input-9-109c63022289> in plot_learning_curve(x, scores, figure_file)
#       5   running_avg = np.zeros(len(scores))
#       6   for i in range(len(running_avg)):
# ----> 7     running_avg[i] = np.mean(score[max(0, i-100):(i+1)])
#       8   plt.plot(x, running_avg)
#       9   plt.title('Running average of previous 100 scores')
#
# TypeError: 'float' object is not subscriptable
